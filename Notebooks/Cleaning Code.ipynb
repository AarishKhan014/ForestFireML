# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(rf'D:\DS_Work\Projects\Regression\Algerian_forest_fires_dataset.csv')
df.columns = df.columns.str.strip()
df.loc[:121, 'Region'] = 'Bejaia'
df.loc[125:, 'Region'] = 'Sidi Belabbes'
df.drop(index=[122,123,124], inplace=True)
df.reset_index(drop=True, inplace=True)
df['Classes'] = df['Classes'].str.strip()
df['Classes'] = df['Classes'].fillna((df['Classes']).mode()[0])
df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']] = df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)
df.drop(index=[165], inplace=True)
df.reset_index(drop=True, inplace=True)
df[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']] = df[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df.to_csv(rf'D:\DS_Work\Projects\Regression\Algerian_forest_fires_CLEANED.csv', index=False)
